# %% [markdown]
# # Hyderabad House Prices Practice Notebook
# Dataset + 30 NumPy & Pandas practice questions.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
'House_ID': np.arange(101,131),
'Location': ['Gachibowli','Madhapur','Kukatpally','Miyapur','Hitech City','Kondapur','Begumpet','Ameerpet','Manikonda','Banjara Hills','Jubilee Hills','LB Nagar','Uppal','Dilsukhnagar','Secunderabad','Gachibowli','Madhapur','Kukatpally','Miyapur','Hitech City','Kondapur','Begumpet','Ameerpet','Manikonda','Banjara Hills','Jubilee Hills','LB Nagar','Uppal','Dilsukhnagar','Secunderabad'],
'Type': ['Apartment','Villa','Apartment','Apartment','Villa','Apartment','Apartment','Apartment','Villa','Villa','Villa','Apartment','Apartment','Apartment','Apartment','Villa','Apartment','Apartment','Apartment','Villa','Apartment','Apartment','Apartment','Villa','Villa','Villa','Apartment','Apartment','Apartment','Apartment'],
'Bedrooms': [2,4,3,2,5,3,2,2,4,5,6,3,2,2,3,4,3,2,2,5,3,2,2,4,5,6,3,2,2,3],
'Bathrooms': [2,4,3,2,5,3,2,2,4,5,6,3,2,2,3,4,3,2,2,5,3,2,2,4,5,6,3,2,2,3],
'Area_Sqft': [1200,3200,1600,1100,4200,1700,1250,1150,2800,5000,6200,1500,1180,1120,1450,3500,1650,1300,1080,4300,1750,1280,1170,2900,5200,6400,1520,1210,1140,1480],
'Age_Years': [5,2,8,10,1,6,12,9,3,2,1,7,11,13,8,4,5,9,10,2,6,12,10,4,3,1,8,11,14,9],
'Parking': [1,2,1,1,3,1,1,1,2,3,4,1,1,1,1,2,1,1,1,3,1,1,1,2,3,4,1,1,1,1],
'Price_Lakhs': [75,280,95,68,420,110,82,78,240,650,850,98,72,70,105,310,102,80,66,430,115,84,79,250,670,880,100,74,69,108],
'Furnished': ['Semi','Full','Semi','Unfurnished','Full','Semi','Unfurnished','Semi','Full','Full','Full','Semi','Unfurnished','Unfurnished','Semi','Full','Semi','Semi','Unfurnished','Full','Semi','Unfurnished','Semi','Full','Full','Full','Semi','Unfurnished','Unfurnished','Semi']
})
df
# Out:
#     House_ID       Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 0        101     Gachibowli  Apartment         2          2       1200
# 1        102       Madhapur      Villa         4          4       3200
# 2        103     Kukatpally  Apartment         3          3       1600
# 3        104        Miyapur  Apartment         2          2       1100
# 4        105    Hitech City      Villa         5          5       4200
# 5        106       Kondapur  Apartment         3          3       1700
# 6        107       Begumpet  Apartment         2          2       1250
# 7        108       Ameerpet  Apartment         2          2       1150
# 8        109      Manikonda      Villa         4          4       2800
# 9        110  Banjara Hills      Villa         5          5       5000
# 10       111  Jubilee Hills      Villa         6          6       6200
# 11       112       LB Nagar  Apartment         3          3       1500
# ...

# %% [markdown]
# ## 30 Practice Questions
# 1. First 5 rows
# 2. Last 5 rows
# 3. Shape
# 4. Columns
# 5. Data types
# 6. Houses where Price_Lakhs > 300
# 7. Villas only
# 8. Houses in Gachibowli
# 9. Apartments with 3 bedrooms
# 10. Houses older than 10 years
# 11. Sort by price ascending
# 12. Sort by area descending
# 13. Sort by age ascending
# 14. Create Price_per_Sqft
# 15. Create Luxury column (Price > 500)
# 16. Average price by Location
# 17. Max price by Type
# 18. Count houses by Furnished
# 19. Average area by Bedrooms
# 20. Total listings by Location and Type
# 21. Missing values each column
# 22. Fill missing Price_Lakhs with mean
# 23. Fill missing Furnished with mode
# 24. Convert Price_Lakhs to NumPy array
# 25. Max/min/mean price using NumPy
# 26. Std deviation of Area_Sqft
# 27. Houses with price > avg using NumPy
# 28. Reshape first 12 prices into 3x4
# 29. Top 5 costly houses
# 30. Correlation Area_Sqft vs Price_Lakhs

# %%
# Write your solutions here
df
# Out:
#     House_ID       Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 0        101     Gachibowli  Apartment         2          2       1200
# 1        102       Madhapur      Villa         4          4       3200
# 2        103     Kukatpally  Apartment         3          3       1600
# 3        104        Miyapur  Apartment         2          2       1100
# 4        105    Hitech City      Villa         5          5       4200
# 5        106       Kondapur  Apartment         3          3       1700
# 6        107       Begumpet  Apartment         2          2       1250
# 7        108       Ameerpet  Apartment         2          2       1150
# 8        109      Manikonda      Villa         4          4       2800
# 9        110  Banjara Hills      Villa         5          5       5000
# 10       111  Jubilee Hills      Villa         6          6       6200
# 11       112       LB Nagar  Apartment         3          3       1500
# ...

# %%
# first 5 rows
df.head()
# Out:
#    House_ID     Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 0       101   Gachibowli  Apartment         2          2       1200
# 1       102     Madhapur      Villa         4          4       3200
# 2       103   Kukatpally  Apartment         3          3       1600
# 3       104      Miyapur  Apartment         2          2       1100
# 4       105  Hitech City      Villa         5          5       4200
#
#    Age_Years  Parking  Price_Lakhs    Furnished
# 0          5        1           75         Semi
# 1          2        2          280         Full
# 2          8        1           95         Semi
# 3         10        1           68  Unfurnished
# 4          1        3          420         Full

# %%
# last 5 rows
df.tail()
# Out:
#     House_ID       Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 25       126  Jubilee Hills      Villa         6          6       6400
# 26       127       LB Nagar  Apartment         3          3       1520
# 27       128          Uppal  Apartment         2          2       1210
# 28       129   Dilsukhnagar  Apartment         2          2       1140
# 29       130   Secunderabad  Apartment         3          3       1480
#
#     Age_Years  Parking  Price_Lakhs    Furnished
# 25          1        4          880         Full
# 26          8        1          100         Semi
# 27         11        1           74  Unfurnished
# 28         14        1           69  Unfurnished
# 29          9        1          108         Semi

# %%
# shape of table
df.shape
# Out:
# (30, 10)

# %%
# columns in a table
df.columns
# Out:
# Index(['House_ID', 'Location', 'Type', 'Bedrooms', 'Bathrooms', 'Area_Sqft',
#        'Age_Years', 'Parking', 'Price_Lakhs', 'Furnished'],
#       dtype='object')

# %%
# data types
df.dtypes
# Out:
# House_ID        int64
# Location       object
# Type           object
# Bedrooms        int64
# Bathrooms       int64
# Area_Sqft       int64
# Age_Years       int64
# Parking         int64
# Price_Lakhs     int64
# Furnished      object
# dtype: object

# %%
# 300 Lakhs more in house price
df[df['Price_Lakhs']>300]
# Out:
#     House_ID       Location   Type  Bedrooms  Bathrooms  Area_Sqft  Age_Years  \
# 4        105    Hitech City  Villa         5          5       4200          1
# 9        110  Banjara Hills  Villa         5          5       5000          2
# 10       111  Jubilee Hills  Villa         6          6       6200          1
# 15       116     Gachibowli  Villa         4          4       3500          4
# 19       120    Hitech City  Villa         5          5       4300          2
# 24       125  Banjara Hills  Villa         5          5       5200          3
# 25       126  Jubilee Hills  Villa         6          6       6400          1
#
#     Parking  Price_Lakhs Furnished
# 4         3          420      Full
# 9         3          650      Full
# 10        4          850      Full
# 15        2          310      Full
# 19        3          430      Full
# 24        3          670      Full
# 25        4          880      Full

# %%
# Villas in different areas
df[df['Type']=='Villa']
# Out:
#     House_ID       Location   Type  Bedrooms  Bathrooms  Area_Sqft  Age_Years  \
# 1        102       Madhapur  Villa         4          4       3200          2
# 4        105    Hitech City  Villa         5          5       4200          1
# 8        109      Manikonda  Villa         4          4       2800          3
# 9        110  Banjara Hills  Villa         5          5       5000          2
# 10       111  Jubilee Hills  Villa         6          6       6200          1
# 15       116     Gachibowli  Villa         4          4       3500          4
# 19       120    Hitech City  Villa         5          5       4300          2
# 23       124      Manikonda  Villa         4          4       2900          4
# 24       125  Banjara Hills  Villa         5          5       5200          3
# 25       126  Jubilee Hills  Villa         6          6       6400          1
#
#     Parking  Price_Lakhs Furnished
# 1         2          280      Full
# 4         3          420      Full
# ...

# %%
# Gochibowli location
df[df['Location']=='Gachibowli']
# Out:
#     House_ID    Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 0        101  Gachibowli  Apartment         2          2       1200
# 15       116  Gachibowli      Villa         4          4       3500
#
#     Age_Years  Parking  Price_Lakhs Furnished
# 0           5        1           75      Semi
# 15          4        2          310      Full

# %%
# apartment and more than 3 Bedrooms
df[(df['Type']=='Apartment') & (df['Bedrooms']==3)]
# Out:
#     House_ID      Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 2        103    Kukatpally  Apartment         3          3       1600
# 5        106      Kondapur  Apartment         3          3       1700
# 11       112      LB Nagar  Apartment         3          3       1500
# 14       115  Secunderabad  Apartment         3          3       1450
# 16       117      Madhapur  Apartment         3          3       1650
# 20       121      Kondapur  Apartment         3          3       1750
# 26       127      LB Nagar  Apartment         3          3       1520
# 29       130  Secunderabad  Apartment         3          3       1480
#
#     Age_Years  Parking  Price_Lakhs Furnished
# 2           8        1           95      Semi
# 5           6        1          110      Semi
# 11          7        1           98      Semi
# 14          8        1          105      Semi
# 16          5        1          102      Semi
# 20          6        1          115      Semi
# ...

# %%
# age greter than 10 years in house 
df[df['Age_Years']>10]
# Out:
#     House_ID      Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 6        107      Begumpet  Apartment         2          2       1250
# 12       113         Uppal  Apartment         2          2       1180
# 13       114  Dilsukhnagar  Apartment         2          2       1120
# 21       122      Begumpet  Apartment         2          2       1280
# 27       128         Uppal  Apartment         2          2       1210
# 28       129  Dilsukhnagar  Apartment         2          2       1140
#
#     Age_Years  Parking  Price_Lakhs    Furnished
# 6          12        1           82  Unfurnished
# 12         11        1           72  Unfurnished
# 13         13        1           70  Unfurnished
# 21         12        1           84  Unfurnished
# 27         11        1           74  Unfurnished
# 28         14        1           69  Unfurnished

# %%
# House prices are ascending 
df.sort_values(by='Price_Lakhs')
# Out:
#     House_ID       Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 18       119        Miyapur  Apartment         2          2       1080
# 3        104        Miyapur  Apartment         2          2       1100
# 28       129   Dilsukhnagar  Apartment         2          2       1140
# 13       114   Dilsukhnagar  Apartment         2          2       1120
# 12       113          Uppal  Apartment         2          2       1180
# 27       128          Uppal  Apartment         2          2       1210
# 0        101     Gachibowli  Apartment         2          2       1200
# 7        108       Ameerpet  Apartment         2          2       1150
# 22       123       Ameerpet  Apartment         2          2       1170
# 17       118     Kukatpally  Apartment         2          2       1300
# 6        107       Begumpet  Apartment         2          2       1250
# 21       122       Begumpet  Apartment         2          2       1280
# ...

# %%
# Area are descending order
df.sort_values(by='Area_Sqft',ascending=False)
# Out:
#     House_ID       Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 25       126  Jubilee Hills      Villa         6          6       6400
# 10       111  Jubilee Hills      Villa         6          6       6200
# 24       125  Banjara Hills      Villa         5          5       5200
# 9        110  Banjara Hills      Villa         5          5       5000
# 19       120    Hitech City      Villa         5          5       4300
# 4        105    Hitech City      Villa         5          5       4200
# 15       116     Gachibowli      Villa         4          4       3500
# 1        102       Madhapur      Villa         4          4       3200
# 23       124      Manikonda      Villa         4          4       2900
# 8        109      Manikonda      Villa         4          4       2800
# 20       121       Kondapur  Apartment         3          3       1750
# 5        106       Kondapur  Apartment         3          3       1700
# ...

# %%
# ages are descending order
df.sort_values(by='Age_Years',ascending=False)
# Out:
#     House_ID       Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 28       129   Dilsukhnagar  Apartment         2          2       1140
# 13       114   Dilsukhnagar  Apartment         2          2       1120
# 21       122       Begumpet  Apartment         2          2       1280
# 6        107       Begumpet  Apartment         2          2       1250
# 12       113          Uppal  Apartment         2          2       1180
# 27       128          Uppal  Apartment         2          2       1210
# 22       123       Ameerpet  Apartment         2          2       1170
# 3        104        Miyapur  Apartment         2          2       1100
# 18       119        Miyapur  Apartment         2          2       1080
# 29       130   Secunderabad  Apartment         3          3       1480
# 17       118     Kukatpally  Apartment         2          2       1300
# 7        108       Ameerpet  Apartment         2          2       1150
# ...

# %%
# add column Sqft_Per_Unit
df['Sqft_Per_Unit']=df['Price_Lakhs']/df['Area_Sqft']

# %%
df
# Out:
#     House_ID       Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 0        101     Gachibowli  Apartment         2          2       1200
# 1        102       Madhapur      Villa         4          4       3200
# 2        103     Kukatpally  Apartment         3          3       1600
# 3        104        Miyapur  Apartment         2          2       1100
# 4        105    Hitech City      Villa         5          5       4200
# 5        106       Kondapur  Apartment         3          3       1700
# 6        107       Begumpet  Apartment         2          2       1250
# 7        108       Ameerpet  Apartment         2          2       1150
# 8        109      Manikonda      Villa         4          4       2800
# 9        110  Banjara Hills      Villa         5          5       5000
# 10       111  Jubilee Hills      Villa         6          6       6200
# 11       112       LB Nagar  Apartment         3          3       1500
# ...

# %%
# add column Luxury are house price more than 500 lakhs
df['Luxury']=df['Price_Lakhs']>500
df
# Out:
#     House_ID       Location       Type  Bedrooms  Bathrooms  Area_Sqft  \
# 0        101     Gachibowli  Apartment         2          2       1200
# 1        102       Madhapur      Villa         4          4       3200
# 2        103     Kukatpally  Apartment         3          3       1600
# 3        104        Miyapur  Apartment         2          2       1100
# 4        105    Hitech City      Villa         5          5       4200
# 5        106       Kondapur  Apartment         3          3       1700
# 6        107       Begumpet  Apartment         2          2       1250
# 7        108       Ameerpet  Apartment         2          2       1150
# 8        109      Manikonda      Villa         4          4       2800
# 9        110  Banjara Hills      Villa         5          5       5000
# 10       111  Jubilee Hills      Villa         6          6       6200
# 11       112       LB Nagar  Apartment         3          3       1500
# ...

# %%
# average of price in each location
df.groupby('Location')['Price_Lakhs'].mean()
# Out:
# Location
# Ameerpet          78.5
# Banjara Hills    660.0
# Begumpet          83.0
# Dilsukhnagar      69.5
# Gachibowli       192.5
# Hitech City      425.0
# Jubilee Hills    865.0
# Kondapur         112.5
# Kukatpally        87.5
# LB Nagar          99.0
# Madhapur         191.0
# Manikonda        245.0
# Miyapur           67.0
# Secunderabad     106.5
# Uppal             73.0
# Name: Price_Lakhs, dtype: float64

# %%
# Max price by type
df.groupby('Type')['Price_Lakhs'].max()
# Out:
# Type
# Apartment    115
# Villa        880
# Name: Price_Lakhs, dtype: int64

# %%
# count houses by furnishedd
df['Furnished'].value_counts()
# Out:
# Furnished
# Semi           12
# Full           10
# Unfurnished     8
# Name: count, dtype: int64

# %%
# average area by bedrooms
df.groupby('Bedrooms')['Area_Sqft'].mean()
# Out:
# Bedrooms
# 2    1181.666667
# 3    1581.250000
# 4    3100.000000
# 5    4675.000000
# 6    6300.000000
# Name: Area_Sqft, dtype: float64

# %%
# Total listings by location and type
df.groupby(['Location','Type']).size()
# Out:
# Location       Type
# Ameerpet       Apartment    2
# Banjara Hills  Villa        2
# Begumpet       Apartment    2
# Dilsukhnagar   Apartment    2
# Gachibowli     Apartment    1
#                Villa        1
# Hitech City    Villa        2
# Jubilee Hills  Villa        2
# Kondapur       Apartment    2
# Kukatpally     Apartment    2
# LB Nagar       Apartment    2
# Madhapur       Apartment    1
#                Villa        1
# Manikonda      Villa        2
# Miyapur        Apartment    2
# Secunderabad   Apartment    2
# Uppal          Apartment    2
# dtype: int64

# %%
# missing values in each column
df.isnull().sum()
# Out:
# House_ID         0
# Location         0
# Type             0
# Bedrooms         0
# Bathrooms        0
# Area_Sqft        0
# Age_Years        0
# Parking          0
# Price_Lakhs      0
# Furnished        0
# Sqft_Per_Unit    0
# Luxury           0
# dtype: int64

# %%
# 24) convert into price_lakhs into numpy array
price=df['Price_Lakhs'].to_numpy()

# %%
price
# Out:
# array([ 75, 280,  95,  68, 420, 110,  82,  78, 240, 650, 850,  98,  72,
#         70, 105, 310, 102,  80,  66, 430, 115,  84,  79, 250, 670, 880,
#        100,  74,  69, 108])

# %%
# 25) max,min , mean() usinng numpy
np.max(price)
# Out:
# np.int64(880)

# %%
np.min(price)
# Out:
# np.int64(66)

# %%
np.mean(price)
# Out:
# np.float64(223.66666666666666)

# %%
# 26) std deviation of area sqft
np.std(df['Area_Sqft'])
# Out:
# 1606.149328881554

# %%
# 27) house with price > avg using numpy
avg=np.mean(price)
df[df['Price_Lakhs']>avg]
# Out:
#     House_ID       Location   Type  Bedrooms  Bathrooms  Area_Sqft  Age_Years  \
# 1        102       Madhapur  Villa         4          4       3200          2
# 4        105    Hitech City  Villa         5          5       4200          1
# 8        109      Manikonda  Villa         4          4       2800          3
# 9        110  Banjara Hills  Villa         5          5       5000          2
# 10       111  Jubilee Hills  Villa         6          6       6200          1
# 15       116     Gachibowli  Villa         4          4       3500          4
# 19       120    Hitech City  Villa         5          5       4300          2
# 23       124      Manikonda  Villa         4          4       2900          4
# 24       125  Banjara Hills  Villa         5          5       5200          3
# 25       126  Jubilee Hills  Villa         6          6       6400          1
#
#     Parking  Price_Lakhs Furnished  Sqft_Per_Unit  Luxury
# ...

# %%
df['Price_Lakhs'].mean()
# Out:
# np.float64(223.66666666666666)

# %%
# 28) reshape of first 12 prices into 3X4
price[:12].reshape(3,4)
# Out:
# array([[ 75, 280,  95,  68],
#        [420, 110,  82,  78],
#        [240, 650, 850,  98]])

# %%
#29) costly 5 houses
df.sort_values(by='Price_Lakhs',ascending=False).head(5)
# Out:
#     House_ID       Location   Type  Bedrooms  Bathrooms  Area_Sqft  Age_Years  \
# 25       126  Jubilee Hills  Villa         6          6       6400          1
# 10       111  Jubilee Hills  Villa         6          6       6200          1
# 24       125  Banjara Hills  Villa         5          5       5200          3
# 9        110  Banjara Hills  Villa         5          5       5000          2
# 19       120    Hitech City  Villa         5          5       4300          2
#
#     Parking  Price_Lakhs Furnished  Sqft_Per_Unit  Luxury
# 25        4          880      Full       0.137500    True
# 10        4          850      Full       0.137097    True
# 24        3          670      Full       0.128846    True
# 9         3          650      Full       0.130000    True
# 19        3          430      Full       0.100000   False

# %%
# correlation area_sqft vs Price_lakhs
df['Area_Sqft'].corr(df['Price_Lakhs'])
# Out:
# np.float64(0.9859508698365943)
